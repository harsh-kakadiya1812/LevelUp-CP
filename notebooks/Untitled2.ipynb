# %%
import sys
sys.path.append('../backend')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data_collection/training_data_verified.csv')

print(f"Shape: {df.shape}")
print(f"Unique users: {df['handle'].nunique()}")
print()
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 8
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#       7
# ----> 8 df = pd.read_csv('../data_collection/training_data_verified.csv')
#       9
#      10 print(f"Shape: {df.shape}")
#      11 print(f"Unique users: {df['handle'].nunique()}")
#
# File D:\cp_coach\cp_project\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File D:\cp_coach\cp_project\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File D:\cp_coach\cp_project\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File D:\cp_coach\cp_project\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File D:\cp_coach\cp_project\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data_collection/training_data_verified.csv'

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in D:\cp_coach\cp_project\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.5 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.5 MB 2.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.5 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.5 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.5 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.5 MB 1.6 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.5 MB 1.5 MB/s eta 0:00:05
#    ------------ --------------------------- 2.9/9.5 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.1/9.5 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.5 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.9/9.5 MB 1.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.2/9.5 MB 1.6 MB/s eta 0:00:04
#    ------------------ --------------------- 4.5/9.5 MB 1.5 MB/s eta 0:00:04
#    --------------------- ------------------ 5.0/9.5 MB 1.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.2/9.5 MB 1.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.5/9.5 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 6.0/9.5 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 6.6/9.5 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.8/9.5 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.1/9.5 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.5 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 7.6/9.5 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 7.9/9.5 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.1/9.5 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 1.6 MB/s  0:00:05
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.0 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.4 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    -------------------------- ------------- 4/6 [contourpy]
#    -------------------------- ------------- 4/6 [contourpy]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    ---------------------------------------- 6/6 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pyparsing-3.3.2

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in D:\cp_coach\cp_project\Lib\site-packages (from seaborn) (2.5.0)
# Requirement already satisfied: pandas>=1.2 in D:\cp_coach\cp_project\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in D:\cp_coach\cp_project\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in D:\cp_coach\cp_project\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in D:\cp_coach\cp_project\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in D:\cp_coach\cp_project\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
